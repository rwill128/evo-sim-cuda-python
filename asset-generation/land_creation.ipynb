# %%
from visualization import land_rendering
import land_creation

# %%
land = land_creation.create_land()

# %%
smooth_land = land_creation.add_smoothing_to_land(land)

# %%
land_rendering.render_land(land)

# %%
land_rendering.render_land(smooth_land)

# %%
smooth_land_with_water = land_creation.lower_all_land_below_threshold(smooth_land, .5)

# %%
"Land min: " + str(land.min()) + " Land max:" + str(land.max())
# Out:
# 'Land min: 6.569670483180801e-07 Land max:0.9999962024019896'

# %%
"Smooth land min: " + str(smooth_land.min()) + " Smooth land max:" + str(smooth_land.max())
# Out:
# 'Smooth land min: 0.22266825207340052 Smooth land max:0.8329691178883393'

# %%
"Smooth land with water min: " + str(smooth_land_with_water.min()) + " Smooth land with water max:" + str(smooth_land_with_water.max())
# Out:
# 'Smooth land with water min: 0.0 Smooth land with water max:0.8329691178883393'

# %%
land_rendering.render_land(smooth_land_with_water)
